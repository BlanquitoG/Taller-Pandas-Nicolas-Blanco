# %% [markdown]
# # Cargar y explorar el dataset

# %%
import pandas as pd
data_estudiantes = pd.read_csv("Student_performance_data _.csv")
data_estudiantes.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# ...

# %%
data_estudiantes.info() #para ver las columnas y filas hay
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
data_estudiantes.describe() # para obtener estadísticas descriptivas de las columnas numéricas del DataFrame
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %% [markdown]
# # Limpieza de datos

# %%
data_estudiantes.isnull().sum() # para verificar si hay valores nulos en el DataFrame
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
data_estudiantes.drop_duplicates(inplace=True) # para eliminar filas duplicadas en el DataFrame, so es que hay alguna

# %%
data_estudiantes_COPY = data_estudiantes.copy()

data_estudiantes_COPY['Gender'] = data_estudiantes_COPY["Gender"].map({0: "Male", 1: "Female"}) #para cambiar los valores del genero y manejarlo mas facil
data_estudiantes_COPY['Sports'] = data_estudiantes_COPY["Sports"].map({0: "No", 1: "Yes"}) #para cambiar los valores de deportes y manejarlo mas facil
data_estudiantes_COPY['Music'] = data_estudiantes_COPY["Music"].map({0: "No", 1: "Yes"}) #para cambiar los valores de musica y manejarlo mas facil

data_estudiantes_COPY.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17  Female          0                  2        19.833723
# 1       1002   18    Male          0                  1        15.408756
# 2       1003   15    Male          2                  3         4.210570
# 3       1004   17  Female          0                  3        10.028829
# 4       1005   17  Female          0                  2         4.672495
# 5       1006   18    Male          0                  1         8.191219
# 6       1007   15    Male          1                  1        15.601680
# 7       1008   15  Female          1                  4        15.424496
# 8       1009   17    Male          0                  0         4.562008
# 9       1010   16  Female          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular Sports Music  \
# 0         7         1                2                0     No   Yes
# ...

# %% [markdown]
# # Filtros

# %%
# mirar si las horas de estudio semanal afectan el rendimiento academico, para esto se puede hacer un filtro y luego sacar la media de cada grupo
estudiantes_con_estudio_largo = data_estudiantes_COPY[data_estudiantes_COPY["StudyTimeWeekly"] > 10]
estudiantes_con_estudio_largo["GPA"].mean() # para sacar la media de las notas finales de los estudiantes con estudio largo
print(estudiantes_con_estudio_largo["GPA"].mean())
#aca el promedio de los que estudian mas de 10h a la semana es de 2.0
# Out:
# 2.048584874333215

# %%
estudiantes_con_estudio_corto = data_estudiantes_COPY[data_estudiantes_COPY["StudyTimeWeekly"] < 10]
estudiantes_con_estudio_corto["GPA"].mean() # para sacar la media de las notas finales de los estudiantes con estudio corto
print(estudiantes_con_estudio_corto["GPA"].mean())
#aca el promedio de los que estudian menos de 10h a la semana es de 1,7
# Out:
# 1.7734496697426134

# %%
#mirar si las actividades extracurriculares y deportes o musica afectan el rendimiento academico
estudiantes_con_deportes_o_musica = data_estudiantes_COPY[
	(data_estudiantes_COPY["Sports"] == "Yes") |
	(data_estudiantes_COPY["Music"] == "Yes")
]
estudiantes_con_deportes_o_musica["GPA"].mean() # para sacar la media de las notas finales de los estudiantes que hacen deportes o música
print(estudiantes_con_deportes_o_musica["GPA"].mean())
# Out:
# 2.0002627448801635

# %%
estudiantes_sin_deportes_ni_musica = data_estudiantes_COPY[
	(data_estudiantes_COPY["Sports"] == "No") &
	(data_estudiantes_COPY["Music"] == "No")
]
estudiantes_sin_deportes_ni_musica["GPA"].mean() # para sacar la media de las notas finales de los estudiantes que no hacen deportes ni música
print(estudiantes_sin_deportes_ni_musica["GPA"].mean())
# Out:
# 1.8309393064817696

# %%
#ver como afecta la absences a clase al rendimiento academico
estudiantes_con_absences_bajas = data_estudiantes_COPY[data_estudiantes_COPY["Absences"] < 15] # <15 por que es la mitad del maximo de absences que es 29
estudiantes_con_absences_bajas["GPA"].mean() # para sacar la media de las notas finales de los estudiantes con absences bajas
print(estudiantes_con_absences_bajas["GPA"].mean())
# Out:
# 2.6411592916747657

# %%
estudiantes_con_absences_altas = data_estudiantes_COPY[data_estudiantes_COPY["Absences"] >= 15] # >=15 por que es la mitad del maximo de absences que es 29
estudiantes_con_absences_altas["GPA"].mean() # para sacar la media de las notas finales de los estudiantes con absences altas
print(estudiantes_con_absences_altas["GPA"].mean())
# Out:
# 1.184609673146055

# %% [markdown]
# Mi hipotesis hasta aqui es la siguiente:
#
# Los estudiantes que tienden a ser estudiar mas tienen mejores notas
#
# Los estudiantes que realizan alguna actividad recreativa tienden a tener mejores notas
#
# Los estudiantes con mas menos ausencias a clases demuestran mas del doble mejor promedio que los que faltan mucho

# %% [markdown]
# # Agrupaciones

# %%
# mirar si el genero afecta el rendimiento academico
genero_academico = data_estudiantes_COPY.groupby("Gender")["GPA"]
print(genero_academico.mean())
# Out:
# Gender
# Female    1.894225
# Male      1.918679
# Name: GPA, dtype: float64

# %%
#mirar si el apoyo parental afecta el rendimiento academico
apoyo_parental_academico = data_estudiantes_COPY.groupby("ParentalSupport")["GPA"]
print(apoyo_parental_academico.mean())
# Out:
# ParentalSupport
# 0    1.540128
# 1    1.755700
# 2    1.884246
# 3    2.042409
# 4    2.191545
# Name: GPA, dtype: float64

# %% [markdown]
# El genero no importa en el rendimiento academico ya que los promedios estan demasiado cerca como para que importe
#
# El apoyo parental tiene un gran impacto en el rendimiento academico

# %% [markdown]
# # Conclusiones

# %% [markdown]
# El rendimiento academico se va afecto por dos factores, el estudiante y su apoy
#
# El estudiante que asiste mas a clase, que estudian mas, y que hace alguna actividad recreativa, ya sea un deporte o artistica, tienden a tener mejores notas en comparacion con los demas
#
# Los estudiantes que tienen mas apoyo parental tienen en promedio mejores notas que los que no, probablente porque los que no tienen ese apoyo tienen que trabajar para poder cubrir sus necesidades, como la habitacion, la comida, la matricula, etc

# %% [markdown]
# # Soluciones

# %% [markdown]
# Fomentar mas a los estudiantes a asistir a clase y hacer actividades recreativos para despejar la mente, ya que se ha demostrado cientificamente que el hacer ejercicio mejora el estado de animo y podria ayudar a los estudiantes a concentrarse mejor en sus estudios
#
# Abrir programas de Becas academicas para que los estudiantes que cuentan con muy poco apoyo parental o nulo, puedan concentrarse mas en sus estudios en vez de trabajar para poder cubrir sus necesidades
